# %% [markdown]
# ## Data Preprocessing Examples
#
#  In this task, we will work on handling missing data as well as data standardisation and normalisation. Data can have missing values for a number of reasons, such as observations that were not collected or data corruption. We will discuss some general considerations for missing data, discuss how pandas chooses to represent it, and demonstrate some built-in pandas tools for handling missing data in Python.

# %%
import pandas as pd
import numpy as np

# Scaling modules
from mlxtend.preprocessing import minmax_scaling, standardize

# Plotting modules
import seaborn as sns
import matplotlib.pyplot as plt

# Ensures the same random data is used each time you execute the code
np.random.seed(0)
# Out:
# c:\Users\A-C19\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Read in data 
df = pd.read_csv('balance_missing.txt', delim_whitespace=True)
# Out:
# C:\Users\A-C19\AppData\Local\Temp\ipykernel_3624\3231046865.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('balance_missing.txt', delim_whitespace=True)

# %% [markdown]
# ## Working with missing data
# ### Take a first look at the data
# This should always be the first step during any analysis. Depending on data sources, missing data are identified differently. Pandas identifies missing values as NaN. However, missing values can appear as a question mark (?) or a zero (0) or minus one (-1) or a blank. So it is important to view and understand your data before anything else.
#
# We are going to use the dataset `balance_missing.txt`. From the first five observations, we can see there are several missing values. They have been represented as NaN.

# %%
# Explore data
df.shape
# Out:
# (400, 11)

# %%
df.head()
# Out:
#             Balance   Income Limit  Rating  Cards   Age  Education  Gender  \
# 0  12.2407984760474   14.891  3606   283.0    2.0   NaN       11.0    Male
# 1  23.2833339223376      NaN  6645   483.0    3.0  82.0       15.0  Female
# 2  22.5304088790893  104.593  7075     NaN    4.0  71.0       11.0    Male
# 3   27.652810710665  148.924  9504   681.0    3.0  36.0       11.0     NaN
# 4  16.8939784904888   55.882  4897   357.0    2.0  68.0       16.0    Male
#
#   Student Married  Ethnicity
# 0      No     Yes  Caucasian
# 1     NaN     Yes      Asian
# 2      No      No      Asian
# 3      No      No      Asian
# 4      No     Yes  Caucasian

# %% [markdown]
# How many NaN values can you point out?
#
# Now that we have seen that there are missing values, we need to get a sense of how many missing values exist in the whole dataset. We are going to find how many missing values we have in each column.

# %%
# Get the number of missing data points per column
missing_values_count = df.isnull().sum()

# Look at the number of missing points in the first ten columns
missing_values_count[0:10]
# Out:
# Balance       0
# Income        6
# Limit        15
# Rating       11
# Cards         1
# Age          10
# Education     6
# Gender        8
# Student       7
# Married       3
# dtype: int64

# %% [markdown]
# To better understand how much data is missing, we can calculate the percentage of all the missing values. If we get a very high percentage, we may be unable to use the data.

# %%
# Total number of missing values
total_cells = np.product(df.shape)
total_missing = missing_values_count.sum()

# Percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 1.7727272727272727

# %% [markdown]
# Only 1.77% of the values are missing.
#
# ### Drop missing values
#
# One option to deal with missing values is to remove any rows or columns that contain missing values. This strategy is not recommended for datasets with important data, sensitive data, or few observations. It's usually worth taking the time to go through your data and interrogate all the columns with missing values to get a proper understanding of your dataset.
#
# If you're sure you want to drop rows with missing values, pandas has a handy function, `dropna()` to do this. Let's try it out on our data.

# %%
# Create a temporary dataframe
temp_df = df

# Remove all the rows that contain a missing value.
temp_df.dropna().head()
# Out:
#             Balance  Income Limit  Rating  Cards   Age  Education  Gender  \
# 4  16.8939784904888  55.882  4897   357.0    2.0  68.0       16.0    Male
# 5  22.4861776123913   80.18  8047   569.0    4.0  77.0       10.0    Male
# 6  10.5745164367595  20.996  3388   259.0    2.0  37.0       12.0  Female
# 7  14.5762043512884  71.408  7114   512.0    2.0  87.0        9.0    Male
# 8  7.93809029500252  15.125  3300   266.0    5.0  66.0       13.0  Female
#
#   Student Married         Ethnicity
# 4      No     Yes         Caucasian
# 5      No      No         Caucasian
# 6      No      No  African American
# 7      No      No             Asian
# 8      No      No         Caucasian

# %% [markdown]
# As you can see, there are no longer NaN values in the first five observations as these have been dropped from the DataFrame. In fact, all observations with a NaN value in any of the columns have been dropped. Below you can see the number of rows has been reduced to 331 compared to 400 in the original dataset.

# %%
temp_df.dropna().shape
# Out:
# (331, 11)

# %% [markdown]
# The above procedure removed observations. Now let us look at removing columns.

# %%
# Create a temporary dataframe
temp_df = df

# Remove all columns with at least one missing value
columns_with_na_dropped = temp_df.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#             Balance
# 0  12.2407984760474
# 1  23.2833339223376
# 2  22.5304088790893
# 3   27.652810710665
# 4  16.8939784904888

# %% [markdown]
# Looks like all the columns had at least one missing value except the "Balance" column. Losing all columns but one reduces the amount of data you have drastically. This is one of the reasons why removing observations or columns with missing data may not be a good solution. We'll explore other options next.

# %% [markdown]
# ### Filling in missing values automatically
#
# We can use the pandas `fillna()` function to fill in missing values in a dataframe. One option is to specify what we want the NaN values to be replaced with. Here, we can replace all NaN with 0.

# %%
# Create a temporary dataframe
temp_df = df

# replace all NA's with 0
temp_df.fillna(0).head()
# Out:
#             Balance   Income Limit  Rating  Cards   Age  Education  Gender  \
# 0  12.2407984760474   14.891  3606   283.0    2.0   0.0       11.0    Male
# 1  23.2833339223376        0  6645   483.0    3.0  82.0       15.0  Female
# 2  22.5304088790893  104.593  7075     0.0    4.0  71.0       11.0    Male
# 3   27.652810710665  148.924  9504   681.0    3.0  36.0       11.0       0
# 4  16.8939784904888   55.882  4897   357.0    2.0  68.0       16.0    Male
#
#   Student Married  Ethnicity
# 0      No     Yes  Caucasian
# 1       0     Yes      Asian
# 2      No      No      Asian
# 3      No      No      Asian
# 4      No     Yes  Caucasian

# %% [markdown]
# Another option is to replace the missing values with the values that come just before or just after it in the same column. This can be used in datasets where the observations are in some sorted or logical order.

# %%
# Create a temporary dataframe
temp_df = df

# Replace all NaN's with the value that comes directly after it in the same column, 
# then replace all the remaining NaN's with 0
temp_df.fillna(method = 'bfill', axis=0).fillna(0).head()
# Out:
# C:\Users\A-C19\AppData\Local\Temp\ipykernel_3624\727922078.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   temp_df.fillna(method = 'bfill', axis=0).fillna(0).head()
#             Balance   Income Limit  Rating  Cards   Age  Education  Gender  \
# 0  12.2407984760474   14.891  3606   283.0    2.0  82.0       11.0    Male
# 1  23.2833339223376  104.593  6645   483.0    3.0  82.0       15.0  Female
# 2  22.5304088790893  104.593  7075   681.0    4.0  71.0       11.0    Male
# 3   27.652810710665  148.924  9504   681.0    3.0  36.0       11.0    Male
# 4  16.8939784904888   55.882  4897   357.0    2.0  68.0       16.0    Male
#
#   Student Married  Ethnicity
# 0      No     Yes  Caucasian
# 1      No     Yes      Asian
# 2      No      No      Asian
# 3      No      No      Asian
# 4      No     Yes  Caucasian

# %% [markdown]
# ### Feature Scaling Recap
# Recall feature scaling is the process of restricting the values in a particular feature to ensure that all features lie on the same scale. There are two main types of feature scaling: standardisation and normalisation.
#
# #### Standardisation vs. Normalisation: What's the difference?
# One of the reasons that it's easy to get confused between standardisation and normalisation is because the terms are sometimes used interchangeably and, to make it even more confusing, they are very similar! In both cases, you're transforming the values of numeric variables so that the transformed data points have specific helpful properties. The difference is that, in standardisation, you're changing the range of your data to have a mean of 0 and a standard deviation of 1, while in normalisation you're changing the range of your data to have a maximum of 1 and a minimum of 0.

# %% [markdown]
# #### Standarisation example

# %%
# Generate 1000 data points randomly drawn from an normal distribution
original_data = np.random.normal(loc=10, scale=5, size = 1000)

# Use minmax to standardise the data
scaled_data = standardize(original_data, columns = [0])

# Plot the orginal and scaled data to compare
fig, ax=plt.subplots(1,2)
sns.histplot(original_data, ax=ax[0],kde=True)
ax[0].set_title("Original Data")
sns.histplot(scaled_data, ax=ax[1],kde=True)
ax[1].set_title("Scaled data")
# Out:
# c:\Users\A-C19\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\A-C19\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\A-C19\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Text(0.5, 1.0, 'Scaled data')

# %% [markdown]
# Notice that the standardised data has a mean of 0.

# %% [markdown]
# #### Normalisation example

# %%
# Generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size = 1000)

# Use minmax to normalise the data 
scaled_data = minmax_scaling(original_data, columns = [0])

# Plot the orginal and scaled data to compare
fig, ax=plt.subplots(1,2)
sns.histplot(original_data, ax=ax[0],kde=True)
ax[0].set_title("Original Data")
sns.histplot(scaled_data, ax=ax[1],kde=True)
ax[1].set_title("Scaled data")
# Out:
# c:\Users\A-C19\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\A-C19\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\A-C19\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Text(0.5, 1.0, 'Scaled data')

# %% [markdown]
# Notice that, instead of ranging from 0 to ~8, it now ranges from 0 to 1.

# %% [markdown]
# ## Practice
#
# Practice handing missing data with the "countries.csv" dataset which is derived from some World Bank data. Each column is a type of indicator for example EN.ATM.CO2E.PC is carbon dioxide emissions in metric tons per capita. These indicators are recorded for participating countries.

# %%
# Load countries data
countries = pd.read_csv("countries.csv")

countries.head()
# Out:
#   Country                               Country Groups  BX.KLT.DINV.WD.GD.ZS  \
# 0     CEB               Central Europe and the Baltics              1.555790
# 1     CSS                       Caribbean small states              4.658176
# 2     EAP  East Asia & Pacific (excluding high income)              3.796483
# 3     EAR                   Early-demographic dividend              2.073571
# 4     EAS                          East Asia & Pacific              2.930966
#
#    EG.ELC.ACCS.ZS  EG.FEC.RNEW.ZS  EN.ATM.CO2E.PC  FP.CPI.TOTL.ZG  \
# 0      100.000000       14.538355        6.820042        1.840965
# 1       93.114511        9.096342        9.277109        3.250344
# 2       94.997330       16.471817        5.106045        3.789836
# 3       79.455104       26.481427        2.119827        4.580200
# 4       95.496185       13.729447        5.701783        3.247588
#
#    IT.CEL.SETS.P2  IT.NET.USER.ZS  NE.EXP.GNFS.ZS  ...  NY.GDP.PCAP.CD  \
# 0      122.192106       58.599297       52.333390  ...    12567.128310
# 1      113.628492       35.407690       44.935642  ...     8726.326154
# 2       69.905604       28.957482       30.572597  ...     4007.323783
# 3       68.069446       12.835425       27.711023  ...     2926.483907
# 4       73.657018       34.269800       32.153225  ...     7674.475705
#
#    SP.DYN.AMRT.FE  SP.DYN.AMRT.MA  SP.DYN.CBRT.IN  SP.DYN.CDRT.IN  \
# 0       77.039930      189.578062       10.543330       11.429917
# 1      121.928584      200.568068       17.555646        7.436407
# 2       91.717833      134.835195       14.439063        7.019396
# 3      150.595639      214.978616       22.914627        7.028941
# 4       86.702958      130.465277       13.880915        7.095146
#
#    SP.DYN.IMRT.IN  SP.DYN.LE00.IN  SP.DYN.TFRT.IN  SP.POP.GROW  \
# 0        6.019183       75.295349        1.465325    -0.362710
# 1       18.406085       72.252392        2.151960     0.642147
# 2       19.100000       73.482345        1.843869     0.713160
# 3       40.042149       67.955732        2.763140     1.534541
# 4       18.136433       74.383915        1.797065     0.675231
#
#    SP.URB.TOTL.IN.ZS
# 0          62.059417
# 1          42.083135
# 2          47.696831
# 3          42.113134
# 4          51.791229
#
# [5 rows x 21 columns]

# %%
# Visualise the IT.CEL.SETS.P2 feature. 
# IT.CEL.SETS.P2 is the mobile cellular subscriptions per 100 people.
sns.histplot(countries['IT.CEL.SETS.P2'])
# Out:
# c:\Users\A-C19\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='IT.CEL.SETS.P2', ylabel='Count'>

# %%
# Scale the data using normalisation since the data does not have a Gaussian (normal) distribution. 
scaled_data = minmax_scaling(countries['IT.CEL.SETS.P2'], columns = [0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Scale the data using normalisation since the data does not have a Gaussian (normal) distribution.
# ----> 2 scaled_data = minmax_scaling(countries['IT.CEL.SETS.P2'], columns = [0])
#
# File c:\Users\A-C19\anaconda3\Lib\site-packages\mlxtend\preprocessing\scaling.py:40, in minmax_scaling(array, columns, min_val, max_val)
#      38 ary_new = array.astype(float)
#      39 if len(ary_new.shape) == 1:
# ---> 40     ary_new = ary_new[:, np.newaxis]
#      42 if isinstance(ary_new, pd.DataFrame):
#      43     ary_newt = ary_new.loc
#
# File c:\Users\A-C19\anaconda3\Lib\site-packages\pandas\core\series.py:1144, in Series.__getitem__(self, key)
#    1141     key = np.asarray(key, dtype=bool)
#    1142     return self._get_rows_with_mask(key)
# -> 1144 return self._get_with(key)
#
# File c:\Users\A-C19\anaconda3\Lib\site-packages\pandas\core\series.py:1154, in Series._get_with(self, key)
#    1149     raise TypeError(
#    1150         "Indexing a Series with DataFrame is not "
#    1151         "supported, use the appropriate DataFrame column"
#    1152     )
#    1153 elif isinstance(key, tuple):
# -> 1154     return self._get_values_tuple(key)
#    1156 elif not is_list_like(key):
#    1157     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1158     return self.loc[key]
#
# File c:\Users\A-C19\anaconda3\Lib\site-packages\pandas\core\series.py:1194, in Series._get_values_tuple(self, key)
#    1189 if com.any_none(*key):
#    1190     # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1191     #  see tests.series.timeseries.test_mpl_compat_hack
#    1192     # the asarray is needed to avoid returning a 2D DatetimeArray
#    1193     result = np.asarray(self._values[key])
# -> 1194     disallow_ndim_indexing(result)
#    1195     return result
#    1197 if not isinstance(self.index, MultiIndex):
#
# File c:\Users\A-C19\anaconda3\Lib\site-packages\pandas\core\indexers\utils.py:341, in disallow_ndim_indexing(result)
#     333 """
#     334 Helper function to disallow multi-dimensional indexing on 1D Series/Index.
#     335
#    (...)
#     338 in GH#30588.
#     339 """
#     340 if np.ndim(result) > 1:
# --> 341     raise ValueError(
#     342         "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     343         "supported. Convert to a numpy array before indexing instead."
#     344     )
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %% [markdown]
# ## Compulsory Tasks

# %% [markdown]
# ### Compulsory Task 1

# %%
# 1. Read in store_income_task.csv
si = pd.read_csv('store_income_data_task.csv')

# 2. Display the first 5 observations
si.head()
# Out:
#    id                   store_name         store_email  department  \
# 0   1   Cullen/Frost Bankers, Inc.                 NaN    Clothing
# 1   2          Nordson Corporation                 NaN       Tools
# 2   3        Stag Industrial, Inc.                 NaN      Beauty
# 3   4          FIRST REPUBLIC BANK  ecanadine3@fc2.com  Automotive
# 4   5  Mercantile Bank Corporation                 NaN        Baby
#
#          income date_measured          country
# 0  $54438554.24      4-2-2006   United States/
# 1  $41744177.01      4-1-2006          Britain
# 2  $36152340.34     12-9-2003    United States
# 3   $8928350.04      8-5-2006         Britain/
# 4  $33552742.32     21-1-1973   United Kingdom

# %%
# 3. Get the number of missing data points per column

missing_values_count = si.isnull().sum()


# 4. Identify the number of missing values in the first ten columns
missing_values_count[0:10]
# Out:
# id                 0
# store_name         0
# store_email      587
# department        27
# income             0
# date_measured      0
# country           35
# dtype: int64

# %% [markdown]
# 5. Write a note on why you think we have missing data for the following three columns: store_email,  department, and country. Remember to classify them according to the three categories(types of missingness) we analysed in the task.

# %% [markdown]
# **Answer here:**

# %% [markdown]
# store_email - MNAR - depending on who has filled out the dataframe they may not have access to the relevant email address.
# The missingness is related to a factor (which employee has completed form) which is not measured by the daraframe
#
# department - MNAR - the departments missingness could be based off how many departments that company have - if they only have 1 department they are unlikley to specify which department this applies to.
#
# country - MCAR - the country on which the bank is in could have been missed by accident, the missing of this data is not based on any other variable measured in the data set or not.

# %% [markdown]
# ### Compulsory Task 2

# %% [markdown]
# 1. For the following example, decide whether standardisation or normalisation makes more sense.
#
#   a. You want to build a linear regression model to predict someone's grades, given how much time they spend on various activities during a typical school week.  You notice that your measurements for how much time students spend studying aren't normally distributed: some students spend almost no time studying, while others study for four or more hours daily. Should you standardise or normalise this variable?
#
#   b. You're still working with your student's grades, but you want to include information on how students perform on several fitness tests as well. You have information on how many jumping jacks and push-ups each student can complete in a minute. However, you notice that students perform far more jumping jacks than push-ups: the average for the former is 40, and for the latter only 10. Should you standardise or normalise these variables?

# %% [markdown]
# **Answer here:**
#
# a. Normalise
#
# b. Standardise

# %%
# Read in the data
countries = pd.read_csv('countries.csv')

# 2. Display the first 5 observations
countries.head()
# Out:
#   Country                               Country Groups  BX.KLT.DINV.WD.GD.ZS  \
# 0     CEB               Central Europe and the Baltics              1.555790
# 1     CSS                       Caribbean small states              4.658176
# 2     EAP  East Asia & Pacific (excluding high income)              3.796483
# 3     EAR                   Early-demographic dividend              2.073571
# 4     EAS                          East Asia & Pacific              2.930966
#
#    EG.ELC.ACCS.ZS  EG.FEC.RNEW.ZS  EN.ATM.CO2E.PC  FP.CPI.TOTL.ZG  \
# 0      100.000000       14.538355        6.820042        1.840965
# 1       93.114511        9.096342        9.277109        3.250344
# 2       94.997330       16.471817        5.106045        3.789836
# 3       79.455104       26.481427        2.119827        4.580200
# 4       95.496185       13.729447        5.701783        3.247588
#
#    IT.CEL.SETS.P2  IT.NET.USER.ZS  NE.EXP.GNFS.ZS  ...  NY.GDP.PCAP.CD  \
# 0      122.192106       58.599297       52.333390  ...    12567.128310
# 1      113.628492       35.407690       44.935642  ...     8726.326154
# 2       69.905604       28.957482       30.572597  ...     4007.323783
# 3       68.069446       12.835425       27.711023  ...     2926.483907
# 4       73.657018       34.269800       32.153225  ...     7674.475705
#
#    SP.DYN.AMRT.FE  SP.DYN.AMRT.MA  SP.DYN.CBRT.IN  SP.DYN.CDRT.IN  \
# 0       77.039930      189.578062       10.543330       11.429917
# 1      121.928584      200.568068       17.555646        7.436407
# 2       91.717833      134.835195       14.439063        7.019396
# 3      150.595639      214.978616       22.914627        7.028941
# 4       86.702958      130.465277       13.880915        7.095146
#
#    SP.DYN.IMRT.IN  SP.DYN.LE00.IN  SP.DYN.TFRT.IN  SP.POP.GROW  \
# 0        6.019183       75.295349        1.465325    -0.362710
# 1       18.406085       72.252392        2.151960     0.642147
# 2       19.100000       73.482345        1.843869     0.713160
# 3       40.042149       67.955732        2.763140     1.534541
# 4       18.136433       74.383915        1.797065     0.675231
#
#    SP.URB.TOTL.IN.ZS
# 0          62.059417
# 1          42.083135
# 2          47.696831
# 3          42.113134
# 4          51.791229
#
# [5 rows x 21 columns]

# %%
# 2. From the countries dataset, visualise the "EG.ELC.ACCS.ZS" column using a histogram.  

plt.hist(countries["EG.ELC.ACCS.ZS"], bins=10, color='skyblue', alpha=0.5, label='EG.ELC.ACCS.ZS')
plt.xlabel("EG.ELC.ACCS.ZS")
plt.ylabel("Frequency")
plt.title("Histogram of Countries Dataset EG.ELC.ACCS.ZS")
plt.legend()
plt.show()

# %%
# Then, scale the column using the appropriate scaling method (normalisation or standardisaton).

from sklearn.preprocessing import MinMaxScaler

# Select the column 'EG.ELC.ACCS.ZS' from the DataFrame
column_to_normalize = countries['EG.ELC.ACCS.ZS'].values.reshape(-1, 1)

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the selected column
normalized_column = scaler.fit_transform(column_to_normalize)

# Assign the normalized values back to the DataFrame
countries['EG.ELC.ACCS.ZS'] = normalized_column

# Display the DataFrame after normalization
print(countries)
# Out:
#    Country                                     Country Groups  \
# 0      CEB                     Central Europe and the Baltics
# 1      CSS                             Caribbean small states
# 2      EAP        East Asia & Pacific (excluding high income)
# 3      EAR                         Early-demographic dividend
# 4      EAS                                East Asia & Pacific
# 5      ECA      Europe & Central Asia (excluding high income)
# 6      ECS                              Europe & Central Asia
# 7      EMU                                          Euro area
# 8      EUU                                     European Union
# 9      FCS           Fragile and conflict affected situations
# 10     FSM                              Micronesia, Fed. Sts.
# 11     HIC                                        High income
# 12     HPC             Heavily indebted poor countries (HIPC)
# 13     IBD                                          IBRD only
# 14     IBT                                   IDA & IBRD total
# 15     IDA                                          IDA total
# 16     IDB                                          IDA blend
# 17     IDX                                           IDA only
# 18     LAC  Latin America & Caribbean (excluding high income)
# 19     LCN                          Latin America & Caribbean
# 20     LDC       Least developed countries: UN classification
# 21     LIC                                         Low income
# 22     LMC                                Lower middle income
# 23     LMY                                Low & middle income
# 24     LTE                          Late-demographic dividend
# 25     MEA                         Middle East & North Africa
# 26     MIC                                      Middle income
# 27     MNA  Middle East & North Africa (excluding high inc...
# 28     OED                                       OECD members
# 29     OSS                                 Other small states
# 30     PRE                           Pre-demographic dividend
# 31     PSS                        Pacific island small states
# 32     PST                          Post-demographic dividend
# 33     SSA         Sub-Saharan Africa (excluding high income)
# 34     SSF                                 Sub-Saharan Africa
# 35     SST                                       Small states
# 36     TEA         East Asia & Pacific (IDA & IBRD countries)
# 37     TEC       Europe & Central Asia (IDA & IBRD countries)
# 38     TLA  Latin America & the Caribbean (IDA & IBRD coun...
# 39     TMN  Middle East & North Africa (IDA & IBRD countries)
# 40     TSA                            South Asia (IDA & IBRD)
# 41     TSS          Sub-Saharan Africa (IDA & IBRD countries)
# 42     UMC                                Upper middle income
# 43     WLD                                              World
#
#     BX.KLT.DINV.WD.GD.ZS  EG.ELC.ACCS.ZS  EG.FEC.RNEW.ZS  EN.ATM.CO2E.PC  \
# 0               1.555790        1.000000       14.538355        6.820042
# 1               4.658176        0.910477        9.096342        9.277109
# 2               3.796483        0.934957       16.471817        5.106045
# 3               2.073571        0.732882       26.481427        2.119827
# 4               2.930966        0.941443       13.729447        5.701783
# 5               2.841455        0.993479        6.287939        7.520215
# 6               3.311091        0.997041       10.833148        7.540721
# 7               4.020539        1.000000       12.833088        7.425634
# 8               3.402097        1.000000       12.960029        7.354521
# 9               3.435664        0.230354       51.769428        0.833551
# 10              0.269791        0.538851        1.500334        1.097099
# 11              2.599367        0.999795        9.526558       11.562960
# 12              4.656115        0.062691       80.198571        0.221203
# 13              3.108258        0.888937       17.872047        4.121492
# 14              3.091863        0.749136       23.357177        3.271113
# 15              2.853402        0.298245       66.824234        0.523641
# 16              2.049943        0.536972       61.903298        0.907668
# 17              3.706545        0.180789       71.632632        0.332242
# 18              3.032455        0.944742       28.621615        2.761717
# 19              3.261416        0.946835       28.331401        2.905129
# 20              2.507053        0.122571       76.669035        0.269364
# 21              4.308013        0.000000       81.007145        0.264876
# 22              2.093759        0.680409       40.399181        1.345907
# 23              3.023092        0.744339       23.497013        3.224270
# 24              4.183336        0.979013       14.633152        6.076496
# 25              3.178368        0.947761        1.922598        5.847629
# 26              3.006615        0.824142       21.203821        3.540673
# 27              1.848351        0.939543        2.759434        3.818796
# 28              2.202096        0.998954       10.241596       10.172343
# 29             11.555964        0.538192       30.746787        6.564310
# 30              2.395405        0.116008       76.332188        0.466651
# 31              9.068878        0.591312       31.483044        1.096409
# 32              2.435132        0.999952        9.858593       11.088100
# 33              2.294643        0.124039       71.443341        0.850299
# 34              2.304839        0.124124       71.422468        0.850715
# 35             10.425761        0.614822       27.003716        6.760790
# 36              3.796429        0.945905       16.492741        5.136588
# 37              2.972856        0.994041        6.562926        7.587861
# 38              3.237232        0.945407       28.731619        2.864984
# 39              1.847225        0.938863        2.718620        3.856529
# 40              1.545553        0.676486       41.588760        1.207519
# 41              2.304839        0.124124       71.422468        0.850715
# 42              3.273893        0.984967       13.495764        5.996112
# 43              2.732319        0.785981       17.255192        4.828062
#
#     FP.CPI.TOTL.ZG  IT.CEL.SETS.P2  IT.NET.USER.ZS  NE.EXP.GNFS.ZS  ...  \
# 0         1.840965      122.192106       58.599297       52.333390  ...
# 1         3.250344      113.628492       35.407690       44.935642  ...
# 2         3.789836       69.905604       28.957482       30.572597  ...
# 3         4.580200       68.069446       12.835425       27.711023  ...
# 4         3.247588       73.657018       34.269800       32.153225  ...
# 5         6.281059      122.828868       35.800430       30.531140  ...
# 6         2.390258      120.365587       56.094025       37.982026  ...
# 7         1.529639      117.103652       70.966005       38.772603  ...
# 8         1.669887      118.568323       70.713150       38.325606  ...
# 9         3.624989       38.270423        5.971161       35.562683  ...
# 10             NaN       26.557674       20.000000       23.513744  ...
# 11        1.961885      109.042068       72.285537       29.454649  ...
# 12        4.700550       36.884260        4.723077       29.323019  ...
# 13        4.336842       78.855715       24.815064       27.988942  ...
# 14        4.406841       70.595568       20.545767       27.723529  ...
# 15        4.548982       43.824852        6.465312       23.519416  ...
# 16        3.436509       57.513685        9.572493       22.789028  ...
# 17        5.048937       37.080514        4.893792       24.175957  ...
# 18        3.859509       95.249241       34.202458       19.933027  ...
# 19        3.556124       96.147712       34.711889       21.699066  ...
# 20        5.982348       32.987287        4.128909       26.843154  ...
# 21        3.665655       28.254610        3.246713       24.611963  ...
# 22        5.997979       66.902830       10.936176       27.134347  ...
# 23        4.462753       69.645706       20.089811       27.260377  ...
# 24        3.288060       82.966233       36.033683       32.148960  ...
# 25        3.913043       91.181964       24.872679       45.226016  ...
# 26        4.580200       74.063530       21.817085       27.291790  ...
# 27        3.989841       80.332857       20.733304       31.888345  ...
# 28        1.813535      101.576549       67.640530       26.118637  ...
# 29        3.165169       86.723586       24.191917       62.168492  ...
# 30        3.976553       44.186577        6.099754       32.936014  ...
# 31             NaN       54.961185       12.974697       46.410710  ...
# 32        2.188538      105.105883       70.979559       27.495477  ...
# 33        4.257416       44.195995        6.988945       31.792453  ...
# 34        4.116984       44.204790        6.992579       31.844806  ...
# 35        3.228894       90.117398       25.724574       59.076911  ...
# 36        3.789836       70.759095       29.320133       30.572327  ...
# 37        6.142554      122.801761       38.103586       31.859184  ...
# 38        3.707816       97.906546       34.984453       20.811776  ...
# 39        4.193628       80.532820       20.529004       32.007673  ...
# 40        7.581530       58.680104        7.205784       21.130725  ...
# 41        4.116984       44.204790        6.992579       31.844806  ...
# 42        3.618069       82.006193       33.878396       27.336763  ...
# 43        3.491289       76.147222       28.733604       28.806724  ...
#
#     NY.GDP.PCAP.CD  SP.DYN.AMRT.FE  SP.DYN.AMRT.MA  SP.DYN.CBRT.IN  \
# 0     12567.128310       77.039930      189.578062       10.543330
# 1      8726.326154      121.928584      200.568068       17.555646
# 2      4007.323783       91.717833      134.835195       14.439063
# 3      2926.483907      150.595639      214.978616       22.914627
# 4      7674.475705       86.702958      130.465277       13.880915
# 5      7822.762509      113.337110      272.198910       14.984144
# 6     23536.968800       81.835521      183.332690       12.696487
# 7     37617.722310       50.157592      101.464956       10.357849
# 8     33687.588170       56.092781      115.645607       10.751707
# 9      1466.468021      244.004724      299.358954       35.798435
# 10     2861.771348      156.794000      185.220000       23.745000
# 11    39326.952660       59.207508      110.771898       11.572596
# 12      742.471894      268.036287      319.258415       39.074814
# 13     4508.768275      113.874284      181.211244       17.548551
# 14     3691.785060      137.766856      200.567692       21.447068
# 15     1059.372205      229.768158      277.934345       34.021127
# 16     1561.403891      246.138742      287.862904       34.532519
# 17      806.079684      221.655980      272.830827       33.769498
# 18     8641.878140       99.864868      187.880261       18.550663
# 19     8943.357022       98.698837      185.470406       18.351203
# 20      779.854781      224.662784      273.148476       34.489366
# 21      522.028283      262.626557      313.771901       38.253438
# 22     1692.027015      163.758628      231.288790       24.373704
# 23     3588.094124      138.241550      200.654778       21.499568
# 24     6190.836555       83.354673      143.764524       13.124218
# 25     7127.071415      100.149237      150.802194       24.318657
# 26     3916.756249      127.356343      191.298803       19.703325
# 27     4122.811861      103.898960      162.796571       25.054438
# 28    35903.579270       62.213698      116.527110       12.529906
# 29    12214.605700      226.407176      255.461437       25.504079
# 30     1366.224110      290.810865      341.257940       40.754667
# 31     2892.651511      140.914304      211.491516       26.122149
# 32    39449.296660       61.539609      118.394994       11.145054
# 33     1555.310732      302.164602      356.621189       38.829943
# 34     1556.256674      302.138968      356.605652       38.827690
# 35    10945.696350      198.755189      242.560555       23.982316
# 36     4050.262299       91.443387      134.223013       14.440688
# 37     8234.206658      109.653329      264.528798       14.632235
# 38     8861.944198       99.453409      187.204574       18.547761
# 39     4143.288742      103.894876      162.956215       24.958042
# 40     1252.227962      153.982054      215.307878       22.597144
# 41     1556.256674      302.138968      356.605652       38.827690
# 42     6406.226914       91.666813      151.540094       14.477521
# 43     9513.304846      124.844906      185.293628       19.853974
#
#     SP.DYN.CDRT.IN  SP.DYN.IMRT.IN  SP.DYN.LE00.IN  SP.DYN.TFRT.IN  \
# 0        11.429917        6.019183       75.295349        1.465325
# 1         7.436407       18.406085       72.252392        2.151960
# 2         7.019396       19.100000       73.482345        1.843869
# 3         7.028941       40.042149       67.955732        2.763140
# 4         7.095146       18.136433       74.383915        1.797065
# 5        11.101239       17.000000       70.836569        1.847442
# 6        10.202257       10.959420       75.929235        1.727758
# 7         9.420781        3.479136       80.746781        1.579788
# 8         9.723571        4.071447       79.724849        1.611578
# 9         9.675914       64.180460       60.263541        4.793928
# 10        6.272000       32.400000       68.582000        3.460000
# 11        8.281463        5.100000       79.818862        1.702623
# 12        9.952073       62.715200       59.001593        5.342116
# 13        7.372658       28.003518       71.304337        2.148804
# 14        7.805140       40.580301       68.924267        2.645382
# 15        9.200046       61.847514       61.247361        4.408726
# 16       10.152979       70.217130       59.447070        4.482625
# 17        8.731159       57.627285       62.133049        4.372200
# 18        5.754466       19.100000       74.062034        2.205085
# 19        5.798148       18.790295       74.222003        2.190586
# 20        8.851372       59.401463       61.779198        4.486034
# 21        9.942619       63.100000       59.320768        5.203554
# 22        7.800829       47.100000       66.267153        2.984314
# 23        7.796518       40.700000       68.868002        2.652012
# 24        7.446510       14.225871       74.443007        1.685595
# 25        5.165597       23.181759       72.271770        2.877878
# 26        7.566424       36.000000       69.891620        2.412816
# 27        5.458020       24.700000       71.754805        2.896798
# 28        8.050552        7.132978       79.360966        1.789041
# 29        8.599084       46.936011       64.949191        3.298442
# 30       10.984616       67.125730       56.941264        5.608679
# 31        6.034642       23.223902       69.514353        3.428560
# 32        8.945127        4.762276       79.689129        1.661451
# 33       11.048779       65.200000       56.942283        5.249069
# 34       11.048405       65.185421       56.943945        5.248709
# 35        8.215641       41.305675       66.646909        3.066843
# 36        6.997145       19.089889       73.531874        1.842210
# 37       10.997735       16.310017       71.302699        1.811748
# 38        5.753647       18.960090       74.100076        2.205032
# 39        5.479352       24.786772       71.746888        2.881390
# 40        7.360384       49.007568       66.826757        2.744213
# 41       11.048405       65.185421       56.943945        5.248709
# 42        7.304136       15.900000       73.947336        1.816209
# 43        7.876908       37.400000       70.682937        2.508023
#
#     SP.POP.GROW  SP.URB.TOTL.IN.ZS
# 0     -0.362710          62.059417
# 1      0.642147          42.083135
# 2      0.713160          47.696831
# 3      1.534541          42.113134
# 4      0.675231          51.791229
# 5      0.497604          64.281869
# 6      0.386693          70.007745
# 7      0.235742          74.817182
# 8      0.219178          73.714758
# 9      2.449772          39.049597
# 10    -0.331445          22.298000
# 11     0.659096          80.024788
# 12     2.839076          32.362504
# 13     1.005011          49.916589
# 14     1.319963          45.991555
# 15     2.349280          33.315989
# 16     2.435229          38.494351
# 17     2.307044          30.763245
# 18     1.235334          78.119285
# 19     1.209072          78.425229
# 20     2.393216          28.977711
# 21     2.772463          28.701622
# 22     1.572886          36.958353
# 23     1.327722          45.888172
# 24     0.603694          55.197468
# 25     2.152467          62.386510
# 26     1.175235          47.731405
# 27     1.849113          58.808733
# 28     0.663447          78.999914
# 29     2.543913          55.962369
# 30     2.942033          35.993544
# 31     1.335335          36.567986
# 32     0.470363          79.734431
# 33     2.772359          35.249148
# 34     2.772365          35.250894
# 35     2.088010          52.018369
# 36     0.715590          47.537577
# 37     0.429670          63.988603
# 38     1.242578          78.379749
# 39     1.836704          58.632666
# 40     1.439535          30.982708
# 41     2.772365          35.250894
# 42     0.733982          59.777524
# 43     1.216246          51.454179
#
# [44 rows x 21 columns]

# %%
# Finally, visualise the original and scaled data alongside each other. 
# Note EG.ELC.ACCS.ZS is the percentage of the population with access to electricity.

import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of the seaborn plots
sns.set(style="whitegrid")

# Create a figure and axis object
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot the original data
sns.histplot(data=countries, x='EG.ELC.ACCS.ZS', kde=True, ax=axes[0])
axes[0].set_title('Original Data')

# Plot the scaled data
sns.histplot(data=countries, x='EG.ELC.ACCS.ZS', kde=True, ax=axes[1])
axes[1].set_title('Scaled Data')

# Add labels to axes
axes[0].set_xlabel('Percentage of population with access to electricity')
axes[0].set_ylabel('Frequency')

axes[1].set_xlabel('Scaled percentage of population with access to electricity')
axes[1].set_ylabel('Frequency')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# c:\Users\A-C19\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\A-C19\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
